# %%
#https://geoffboeing.com/2016/11/osmnx-python-street-networks/
#tutorial for beginners to setup python and osmnx
#https://richardbeare.github.io/GeospatialStroke/
import folium
import geopandas as gpd
import matplotlib.pyplot as plt
import osmnx as ox
import pandas as pd
import networkx as nx
ox.config(use_cache=True)
# Out:
# Unable to open EPSG support file gcs.csv.  Try setting the GDAL_DATA environment variable to point to the directory containing EPSG csv files.

# %%
# %matplotlib inline

#Hudson Institute
G = ox.graph_from_address('27 Wright St, Clayton, Victoria', distance=1000, network_type='walk')
ox.plot_graph(G)
# Out:
# (<Figure size 544.879x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1e54371e358>)

# %%
#https://blog.ouseful.info/2018/06/29/working-with-openstreetmap-roads-data-using-osmnx/
origin=ox.utils.geocode('27 Wright St, Clayton, Victoria') 
origin_node=ox.get_nearest_node(G,origin)
destination= ox.utils.geocode('Jessie McPherson Private Hospital, Clayton, Victoria')
destination_node=ox.get_nearest_node(G,destination)
route = nx.shortest_path(G, origin_node, destination_node)
ox.plot_graph_route(G, route)
# Out:
# (<Figure size 544.879x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1e54503e710>)

# %%
#https://blog.ouseful.info/2018/06/29/working-with-openstreetmap-roads-data-using-osmnx/
origin=ox.utils.geocode('27 Wright St, Clayton, Victoria') 
origin_node=ox.get_nearest_node(G,origin)
destination= ox.utils.geocode('Monash Childrens Hospital, Clayton, Victoria')
destination_node=ox.get_nearest_node(G,destination)
route = nx.shortest_path(G, origin_node, destination_node)
ox.plot_graph_route(G, route)
# Out:
# (<Figure size 544.879x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1e54374fbe0>)
